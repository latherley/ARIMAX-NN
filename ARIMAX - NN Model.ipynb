# %% [markdown]
# # ARIMAX - NN Model of Police Proactive Efficacy
# Loren Atherley & Carl Sharpe

# %%
from IPython.display import HTML, display
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# Install keras and tensorflow backend (https://keras.io/#installation)

# %% [markdown]
# # Begin With ARIMAX
# Load Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# Load Data

# %%
df = pd.read_csv('timeseries.csv', parse_dates=True, index_col='Date')

# %% [markdown]
# Plot Data

# %%
df[['Onview Rate','Dispatch Rate','Person Rate','Property Rate','Society Rate']].plot()
plt.show()

# %% [markdown]
# Test for Unit Root - Dicky Fuller ADF

# %%
print(sm.tsa.adfuller(df['Onview Rate']))
print(sm.tsa.adfuller(df['Dispatch Rate']))
print(sm.tsa.adfuller(df['Person Rate']))
print(sm.tsa.adfuller(df['Property Rate']))
print(sm.tsa.adfuller(df['Society Rate']))
# Out:
# (-3.48230881088914, 0.0084532368546834, 27, 3297, {'1%': -3.4323349555967604, '5%': -2.862417036057391, '10%': -2.5672368644181542}, -52281.872947012875)
# (-3.459556539146585, 0.009088586991047313, 28, 3296, {'1%': -3.4323355582984356, '5%': -2.8624173022673167, '10%': -2.5672370061423377}, -54466.57886726465)
# (-6.83139645471287, 1.889679544428888e-09, 29, 3295, {'1%': -3.432336161366224, '5%': -2.8624175686388993, '10%': -2.567237147952593}, -70030.6675244542)
# (-5.210048025015963, 8.386155174363445e-06, 27, 3297, {'1%': -3.4323349555967604, '5%': -2.862417036057391, '10%': -2.5672368644181542}, -61673.615163870236)
# (-4.2118598907760045, 0.0006290949377590258, 29, 3295, {'1%': -3.432336161366224, '5%': -2.8624175686388993, '10%': -2.567237147952593}, -68428.44222252819)

# %% [markdown]
# Naive Regression for Baseline

# %%
df['Date']=1
model1=sm.OLS(endog=df['Person Rate'],exog=df['Onview Rate','Dispatch Rate'])
results1=model1.fit()
print(results1.summary())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063             try:
# -> 3064                 return self._engine.get_loc(key)
#    3065             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Onview Rate', 'Dispatch Rate')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4f99794e5342> in <module>()
# ...
